# %% [markdown]
# <a href="https://colab.research.google.com/github/CesarVales/CesarVales/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import cv2 as cv
import matplotlib.pyplot as plt
import os

cv.IMREAD_UNCHANGED
image = cv.imread("/content/drive/MyDrive/dataset/images/9dc92f731aa43451aaccdaabbca220fa.png",cv.IMREAD_UNCHANGED)
plt.imshow(image)
plt.imshow(image)
plt.show()
plt.show()

# %%
def get_images_coord(path):
  images_nucleus_coord = pd.read_csv(path,delimiter=",")
  return images_nucleus_coord

images_coord = get_images_coord("/content/drive/MyDrive/dataset/classifications.csv")

def get_nucleus_coord(fileName):
  file_path = "/content/drive/MyDrive/dataset/images/" + fileName
  cord = pd.DataFrame(images_coord,columns=["image_filename","nucleus_x","nucleus_y"])
  return cord[cord["image_filename"] == (fileName)]

  dataFrame_nucleus_coord = get_images_coord("/content/drive/MyDrive/dataset/classifications.csv")

def extract_image_nucleus(image):
    nucleus_coord = get_nucleus_coord("9dc92f731aa43451aaccdaabbca220fa.png")
    for index,row in nucleus_coord.iterrows():
      x=int(row.nucleus_x)
      y=int(row.nucleus_y)
      cut_image = image[y:y+100,x:x+100]
      plt.imshow(cut_image)
      plt.show()
    return cut_image


(extract_image_nucleus(image))

content = get_images_coord("/content/drive/MyDrive/dataset/classifications.csv")
